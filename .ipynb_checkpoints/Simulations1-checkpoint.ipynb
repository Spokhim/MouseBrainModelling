# %%
from tvb.simulator.lab import *
LOG = get_logger('demo')
from tvb.simulator.plot.tools import *
import numpy as np
import pylab
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (20.0, 10.0)

# %%
'''# Create a connectome. 

con = np.array([[2., 3., 0., 2.],
                       [2., 2., 0., 0.],
                       [0., 0., 2., 2.],
                       [2., 0., 0., 2.]])

con'''

# Load the connectivity data from a zip file. 
con = connectivity.Connectivity.from_file(r'C:\Users\Pok Him\Desktop\paupau.zip')
# Out:
# WARNING  File 'hemispheres' not found in ZIP.

# %%
# Visualize the structural connectivity matrix
plt.subplots()
cs=plt.imshow(np.log10(con.weights), cmap='jet', aspect='equal', interpolation='none')
plt.title('Structural connectivity matrix', fontsize=20)
axcb=plt.colorbar(cs)
axcb.set_label('Log10(weights)', fontsize=20)

# %%
# Set the parameter of the resting state simulation
sim = simulator.Simulator(model=models.ReducedWongWang(w=1.0, I_o=0.3),
                        connectivity=con,
                        coupling=coupling.Linear(a=0.096),
                        integrator=integrators.EulerStochastic(dt=0.1, noise=noise.Additive(nsig=0.000013)),
                        monitors=(monitors.Bold(period=2e3),
                                  monitors.TemporalAverage(period=1e3)),
                        simulation_length=1.2e5).configure()
# Run the resting state simulation
(bold_time, bold_data), _ = sim.run()
# Out:
# ---------------------------------------------------------------------------
# TraitTypeError                            Traceback (most recent call last)
# <ipython-input-7-e3d4c6bc089b> in <module>
#       1 # Set the parameter of the resting state simulation
# ----> 2 sim = simulator.Simulator(model=models.ReducedWongWang(w=1.0, I_o=0.3),
#       3                         connectivity=con,
#       4                         coupling=coupling.Linear(a=0.096),
#       5                         integrator=integrators.EulerStochastic(dt=0.1, noise=noise.Additive(nsig=0.000013)),
#
# ~\Anaconda3\envs\TheVirtualBrain\lib\site-packages\tvb\basic\neotraits\_core.py in __init__(self, **kwargs)
#     173                     )
#     174                 )
# --> 175             setattr(self, k, v)
#     176
#     177         self.tags = {}
#
# ~\Anaconda3\envs\TheVirtualBrain\lib\site-packages\tvb\basic\neotraits\_attr.py in __set__(self, instance, value)
#     563     def __set__(self, instance, value):
#     564         # type: (HasTraits, numpy.ndarray) -> None
# --> 565         super(NArray, self).__set__(instance, value)
#     566
#     567     def __str__(self):
#
# ~\Anaconda3\envs\TheVirtualBrain\lib\site-packages\tvb\basic\neotraits\_attr.py in __set__(self, instance, value)
#     189                 raise TraitAttributeError("can't write final attribute")
#     190
# --> 191         value = self._validate_set(instance, value)
#     192
#     193         instance.__dict__[self.field_name] = value
#
# ~\Anaconda3\envs\TheVirtualBrain\lib\site-packages\tvb\basic\neotraits\_attr.py in _validate_set(self, instance, value)
#     532
#     533     def _validate_set(self, instance, value):
# --> 534         value = super(NArray, self)._validate_set(instance, value)
#     535         if value is None:
#     536             # value is optional and missing, nothing to do here
#
# ~\Anaconda3\envs\TheVirtualBrain\lib\site-packages\tvb\basic\neotraits\_attr.py in _validate_set(self, instance, value)
#     141                 return value
#     142
# --> 143         self.__validate(value)
#     144         return value
#     145
#
# ~\Anaconda3\envs\TheVirtualBrain\lib\site-packages\tvb\basic\neotraits\_attr.py in __validate(self, value)
#      90         """ check field_type and choices """
#      91         if not isinstance(value, self.field_type):
# ---> 92             raise TraitTypeError("Attribute can't be set to an instance of {}".format(type(value)), attr=self)
#      93         if self.choices is not None:
#      94             if value not in self.choices and not (value is None and not self.required):
#
# TraitTypeError: Attribute can't be set to an instance of <class 'float'>
#   attribute tvb.simulator.models.wong_wang.ReducedWongWang.w = NArray(label=':math:`w`', dtype=float64, default=array([0.6]), dim_names=(), ndim=None, required=True)
