# %% [markdown]
# # Investigations of 2nd Order Heterogeneity
#
# Here we have a sigma for E and I populations

# %%
import numpy as np
import pandas as pd
import pylab
import matplotlib.pyplot as plt
from scipy import stats
from matplotlib.colors import ListedColormap
from turbo_colormap import *
import inspect
import os
import csv 
import time
import sys
import glob
import pandas as pd
from pprint import pprint

from tvb.simulator.lab import *
from tvb.simulator.plot.tools import *

# Input Simulation Pipeline
from SimulationPipeline import *
from useful_fns import *

matplotlib.rcParams['figure.figsize'] = (20.0, 10.0)

# 3D Plots
from mpl_toolkits import mplot3d

# %%
# Now Import our data from our data folder:

# Get Scorr csv filenames in a folder
# LCycleCut
Scorr_files = glob.glob("D:\\Simulations\\2020_09_04\\*Scorr*.csv")

# The last number is of hrs_mins_secs HHMMSS

print(Scorr_files)
# Out:
# 020_09_04\\LCycleCut_G[1.85]sig_e1.0sig_i0.4_MouseCortex_Scorr_20200904-162838_.csv', 'D:\\Simulations\\2020_09_04\\LCycleCut_G[1.85]sig_e1.0sig_i0.6000000000000001_MouseCortex_Scorr_20200904-163946_.csv', 'D:\\Simulations\\2020_09_04\\LCycleCut_G[1.85]sig_e1.0sig_i0.8_MouseCortex_Scorr_20200904-165053_.csv', 'D:\\Simulations\\2020_09_04\\LCycleCut_G[1.85]sig_e1.0sig_i1.0_MouseCortex_Scorr_20200904-170201_.csv', 'D:\\Simulations\\2020_09_04\\LCycleCut_G[1.8]sig_e0.0sig_i0.0_MouseCortex_Scorr_20200904-102205_.csv', 'D:\\Simulations\\2020_09_04\\LCycleCut_G[1.8]sig_e0.0sig_i0.2_MouseCortex_Scorr_20200904-102820_.csv', 'D:\\Simulations\\2020_09_04\\LCycleCut_G[1.8]sig_e0.0sig_i0.4_MouseCortex_Scorr_20200904-103432_.csv', 'D:\\Simulations\\2020_09_04\\LCycleCut_G[1.8]sig_e0.0sig_i0.6000000000000001_MouseCortex_Scorr_20200904-104046_.csv', 'D:\\Simulations\\2020_09_04\\LCycleCut_G[1.8]sig_e0.0sig_i0.8_MouseCortex_Scorr_20200904-104700_.csv', 'D:\\Simulations\\2020_09_04\\LCycleCut_G[1.8]sig_e0.0sig_i1.0_MouseCortex_Scorr_20200904-105311_.csv', 'D:\\Simulations\\2020_09_04\\LCycleCut_G[1.8]sig_e0.2sig_i0.0_MouseCortex_Scorr_20200904-105920_.csv', 'D:\\Simulations\\2020_09_04\\LCycleCut_G[1.8]sig_e0.2sig_i0.2_MouseCortex_Scorr_20200904-110530_.csv', 'D:\\Simulations\\2020_09_04\\LCycleCut_G[1.8]sig_e0.2sig_i0.4_MouseCortex_Scorr_20200904-111137_.csv', 'D:\\Simulations\\2020_09_04\\LCycleCut_G[1.8]sig_e0.2sig_i0.6000000000000001_MouseCortex_Scorr_20200904-111742_.csv', 'D:\\Simulations\\2020_09_04\\LCycleCut_G[1.8]sig_e0.2sig_i0.8_MouseCortex_Scorr_20200904-112347_.csv', 'D:\\Simulations\\2020_09_04\\LCycleCut_G[1.8]sig_e0.2sig_i1.0_MouseCortex_Scorr_20200904-112954_.csv', 'D:\\Simulations\\2020_09_04\\LCycleCut_G[1.8]sig_e0.4sig_i0.0_MouseCortex_Scorr_20200904-113600_.csv', 'D:\\Simulations\\2020_09_04\\LCycleCut_G[1.8]sig_e0.4sig_i0.2_MouseCortex_Scorr_20200904-114207_.csv', 'D:\\Simulations\\2020_09_04\\LCycleCut_G[1.8]sig_e0.4sig_i0.4_MouseCortex_Scorr_20200904-114810_.csv', 'D:\\Simulations\\2020_09_04\\LCycleCut_G[1.8]sig_e0.4sig_i0.6000000000000001_MouseCortex_Scorr_20200904-115413_.csv', 'D:\\Simulations\\2020_09_04\\LCycleCut_G[1.8]sig_e0.4sig_i0.8_MouseCortex_Scorr_20200904-120018_.csv', 'D:\\Simulations\\2020_09_04\\LCycleCut_G[1.8]sig_e0.4sig_i1.0_MouseCortex_Scorr_20200904-120621_.csv', 'D:\\Simulations\\2020_09_04\\LCycleCut_G[1.8]sig_e0.6000000000000001sig_i0.0_MouseCortex_Scorr_20200904-121224_.csv', 'D:\\Simulations\\2020_09_04\\LCycleCut_G[1.8]sig_e0.6000000000000001sig_i0.2_MouseCortex_Scorr_20200904-121827_.csv', 'D:\\Simulations\\2020_09_04\\LCycleCut_G[1.8]sig_e0.6000000000000001sig_i0.4_MouseCortex_Scorr_20200904-122507_.csv', 'D:\\Simulations\\2020_09_04\\LCycleCut_G[1.8]sig_e0.6000000000000001sig_i0.6000000000000001_MouseCortex_Scorr_20200904-123223_.csv', 'D:\\Simulations\\2020_09_04\\LCycleCut_G[1.8]sig_e0.6000000000000001sig_i0.8_MouseCortex_Scorr_20200904-123925_.csv', 'D:\\Simulations\\2020_09_04\\LCycleCut_G[1.8]sig_e0.6000000000000001sig_i1.0_MouseCortex_Scorr_20200904-124634_.csv', 'D:\\Simulations\\2020_09_04\\LCycleCut_G[1.8]sig_e0.8sig_i0.0_MouseCortex_Scorr_20200904-125304_.csv', 'D:\\Simulations\\2020_09_04\\LCycleCut_G[1.8]sig_e0.8sig_i0.2_MouseCortex_Scorr_20200904-125918_.csv', 'D:\\Simulations\\2020_09_04\\LCycleCut_G[1.8]sig_e0.8sig_i0.4_MouseCortex_Scorr_20200904-130533_.csv', 'D:\\Simulations\\2020_09_04\\LCycleCut_G[1.8]sig_e0.8sig_i0.6000000000000001_MouseCortex_Scorr_20200904-131147_.csv', 'D:\\Simulations\\2020_09_04\\LCycleCut_G[1.8]sig_e0.8sig_i0.8_MouseCortex_Scorr_20200904-131802_.csv', 'D:\\Simulations\\2020_09_04\\LCycleCut_G[1.8]sig_e0.8sig_i1.0_MouseCortex_Scorr_20200904-132416_.csv', 'D:\\Simulations\\2020_09_04\\LCycleCut_G[1.8]sig_e1.0sig_i0.0_MouseCortex_Scorr_20200904-133029_.csv', 'D:\\Simulations\\2020_09_04\\LCycleCut_G[1.8]sig_e1.0sig_i0.2_MouseCortex_Scorr_20200904-133643_.csv', 'D:\\Simulations\\2020_09_04\\LCycleCut_G[1.8]sig_e1.0sig_i0.4_MouseCortex_Scorr_20200904-1 ...

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
# Out:
# <div id='2fabe393-f364-4df7-a6f6-e7fd834d0dc6'></div>
# <div id='14730301-a170-411a-a45e-4cd0f54af5a8'></div>
